# %%
import scipy.io

# Load the .mat file
data = scipy.io.loadmat('ADHD_part1(1)/ADHD_part1/v1p.mat')

# Print the keys to see what variables are stored
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'v1p'])

# %%
v1p = data['v1p']
v1p.shape
# Out:
# (12258, 19)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
v1p_normalized = scaler.fit_transform(v1p)

# %%
import scipy.io
import matplotlib.pyplot as plt

# Load the .mat file
data = scipy.io.loadmat('ADHD_part1(1)/ADHD_part1/v1p.mat')

# Extract the EEG data (assuming it's stored in a variable called 'eeg_data')
eeg_data = data['v1p']  # Replace 'eeg_data' with the actual variable name in the .mat file

# Plot the EEG data for the first channel (Fz)
plt.figure(figsize=(12, 6))
plt.plot(eeg_data[:, 0])  # First column is Fz
plt.title('EEG Signal for Fz')
plt.xlabel('Time (samples)')
plt.ylabel('Voltage (µV)')
plt.show()

# %%
import csv
